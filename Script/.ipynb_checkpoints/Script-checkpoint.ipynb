# %%
import tabula

# %%
# Read pdf into list of DataFrame
dfs = tabula.read_pdf("rahul.pdf", pages='all')

# %%
dfs
# Out:
# [        Date Details  Unnamed: 0   Debit(-)  Credit(+)  \
#  0      17 March 2024         NaN        NaN        NaN
#  1  17 Mar icici 7003         NaN  16,999.00        NaN
#  2   17 Mar icici4003         NaN   4,500.00        NaN
#  3  19 Mar icici 7003         NaN   4,500.00        NaN
#  4  19 Mar icici 4003         NaN  10,999.00        NaN
#  5             22 Mar         NaN        NaN  28,500.00
#  6   22 Mar hdfc 0308         NaN  10,499.00        NaN
#  7        March Total         NaN  47,497.00  28,500.00
#
#                     Balance
#  0  (Opening Balance: 0.00)
#  1            16,999.00  Dr
#  2            21,499.00  Dr
#  3            25,999.00  Dr
#  4            36,998.00  Dr
#  5             8,498.00  Dr
#  6            18,997.00  Dr
#  7                      NaN  ,
#     03 Apr       indus   5,499.00    24,496.00  Dr
#  0  03 Apr       indus  10,999.00    35,495.00  Dr
#  1  07 Apr  icici 7003  12,898.00    48,393.00  Dr
# ...

# %%
# convert PDF into CSV file
tabula.convert_into("rahul.pdf", "Rahul.csv", output_format="csv", pages='all')

# %%
import pandas as pd

df = pd.read_csv('Rahul.csv')

# %%
df
# Out:
#          Date Details  Unnamed: 1     Debit(-)        Credit(+)  \
# 0       17 March 2024         NaN          NaN              NaN
# 1   17 Mar icici 7003         NaN    16,999.00              NaN
# 2    17 Mar icici4003         NaN     4,500.00              NaN
# 3   19 Mar icici 7003         NaN     4,500.00              NaN
# 4   19 Mar icici 4003         NaN    10,999.00              NaN
# 5              22 Mar         NaN          NaN        28,500.00
# 6    22 Mar hdfc 0308         NaN    10,499.00              NaN
# 7         March Total         NaN    47,497.00        28,500.00
# 8              03 Apr       indus     5,499.00    24,496.00  Dr
# 9              03 Apr       indus    10,999.00    35,495.00  Dr
# 10             07 Apr  icici 7003    12,898.00    48,393.00  Dr
# 11             08 Apr  icici 4003    35,499.00    83,892.00  Dr
# 12             13 Apr  icici 4003    17,665.00  1,01,557.00  Dr
# 13               Date     Details     Debit(-)        Credit(+)
# ...
